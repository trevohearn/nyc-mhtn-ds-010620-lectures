# %%
#connects to mysql and creates database and tables
import config
import mysql.connector
from mysql.connector import errorcode
#database string
endpoint = config.DatabaseEndpoint
name = config.DatabaseName
password = config.DatabasePassword
port = config.DatabasePort
dbName = 'YelpPizza'

cnx = mysql.connector.connect(
    host = endpoint,
    user = name,
    passwd = password,
)


#create database given cursor and name of database
def create_database(cursor, database):
    try:
        cursor.execute(
        "CREATE DATABASE {} DEFAULT CHARACTER SET 'utf8'".format(database))
    except mysql.connector.Error as err:
        print('Failed creating database: {}'.format(err))
        exit(1)

#create tables from dictionary
def create_tables(tables, cursor):
    for table_name in tables:
        table_description = tables[table_name]
        try:
            print("Creating table {}: ".format(table_name), end='')
            cursor.execute(table_description)
        except mysql.connector.Error as err:
            if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
                print('already exists')
            else:
                print(err.msg)
        else:
            print('OK')





cur = cnx.cursor()
#CREATE DATABASE AND TABLE SETUP

try:
    cur.execute("USE {}".format(dbName))
except mysql.connector.Error as err:
    print("Database {} does not exist.".format(dbName))
    if err.errno == errorcode.ER_BAD_DB_ERROR:
        create_database(cursor, dbName)
        print("Database {} created successfully.".format(dbName))
        cnx.database = dbName
    else:
        print(err)
        exit(1)     
        


#TABLE SETUP
TABLES = {}
TABLES['businesses'] ="""
CREATE TABLE businesses (
  businesses_id VARCHAR(255) PRIMARY KEY,
  businesses_name VARCHAR(255) NOT NULL,
  businesses_review_count INT,
  businesses_rating DECIMAL(10,2),
  businesses_price INT, 
  businesses_address VARCHAR(255)
)
"""
TABLES['reviews'] ="""
CREATE TABLE YelpPizza.reviews (
  reviews_id VARCHAR(255) PRIMARY KEY,
  reviews_text VARCHAR(5000),
  reviews_rating DECIMAL(10, 2),
  reviews_time_created DATE,
  reviews_user VARCHAR(255)
)
"""

create_tables(TABLES, cur)
# Out:
# Creating table businesses: OK
# Creating table reviews: already exists

# %%
#connects to yelp api and pulls businesses data
import requests
import json
import config

API_KEY=config.APIKey
SEARCH_LIMIT = 50
currentOffset = 0


headers = {'Authorization': 'bearer %s'% API_KEY}

#businesses keys
businessKeys = ['id', 'name', 'review_count', 'rating', 'price', 'location']
#review keys
reviewKeys = []
#insert statements
add_business = ("INSERT INTO YelpPizza.businesses"
                "(businesses_id, businesses_name, businesses_review_count,"
                "businesses_rating, businesses_price, businesses_address) "
                "VALUES (%s, %s, %s, %s ,%s, %s)")
('stuff, sss', 'data')

def businessCallGET(args):
    businessEndpoint = 'https://api.yelp.com/v3/businesses/search'
    return requests.get(businessEndpoint, params=args, headers=headers)
while currentOffset < 1:
    #update params to pass
    params={'term':'pizza place','location':'Brooklyn NY',
        'limit': SEARCH_LIMIT, 'offset':currentOffset}
    #pass and get data from api
    data = businessCallGET(params).json()
    print(data)
    #clean data
    cleanBusinessAndInsert(data, businessKeys, add_business)
    #increment offset for new data
    currentOffset += 50
# Out:
# {'businesses': [{'id': 'sUvoBG8t3eKC7WhJbnro2w', 'alias': 'the-pizza-place-hewlett', 'name': 'The Pizza Place', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/19ybffZ3cvRMqzZpSWaJrw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-pizza-place-hewlett?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg', 'review_count': 92, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}], 'rating': 3.5, 'coordinates': {'latitude': 40.640716, 'longitude': -73.699516}, 'transactions': [], 'price': '$$', 'location': {'address1': '1344 Broadway', 'address2': '', 'address3': '', 'city': 'Hewlett', 'zip_code': '11557', 'country': 'US', 'state': 'NY', 'display_address': ['1344 Broadway', 'Hewlett, NY 11557']}, 'phone': '+15163745900', 'display_phone': '(516) 374-5900', 'distance': 20271.82979363579}, {'id': 'EsHcyOLHaK76bQuU7bwiTw', 'alias': 'tonys-pizzeria-and-restaurant-brooklyn-3', 'name': "Tony's Pizzeria & Restaurant", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wEPzpmEQ2Hd-WkeKUGe1Kg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/tonys-pizzeria-and-restaurant-brooklyn-3?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg', 'review_count': 286, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}], 'rating': 4.5, 'coordinates': {'latitude': 40.699286, 'longitude': -73.918724}, 'transactions': ['pickup', 'delivery'], 'price': '$', 'location': {'address1': '443 Knickerbocker Ave', 'address2': '', 'address3': '', 'city': 'Brooklyn', 'zip_code': '11237', 'country': 'US', 'state': 'NY', 'display_address': ['443 Knickerbocker Ave', 'Brooklyn, NY 11237']}, 'phone': '+17184559664', 'display_phone': '(718) 455-9664', 'distance': 5503.669556667695}, {'id': 'AbDiDY7kYDSldaKbGpoSlg', 'alias': 'the-brooklyn-firefly-brooklyn', 'name': 'The Brooklyn Firefly', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4bTWP3GhL1kjuhlsduC71w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-brooklyn-firefly-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg', 'review_count': 215, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 40.63468, 'longitude': -74.02631}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '7003 3rd Ave', 'address2': '', 'address3': None, 'city': 'Brooklyn', 'zip_code': '11209', 'country': 'US', 'state': 'NY', 'display_address': ['7003 3rd Ave', 'Brooklyn, NY 11209']}, 'phone': '+17188335000', 'display_phone': '(718) 833-5000', 'distance': 7588.967605653356}, {'id': '3VJwpmmeoPlCN3J5p5miEQ', 'alias': 'brooklyns-homeslice-pizzeria-brooklyn', 'name': "Brooklyn's Homeslice Pizzeria", 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0CxtRC4BfPobAfvBBLJH3g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/brooklyns-homeslice-pizzeria-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg', 'review_count': 109, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}], 'rating': 4.5, 'coordinates': {'latitude': 40.680702, 'longitude': -73.967455}, 'transactions': ['pickup', 'delivery'], 'price': '$', 'location': {'address1': '567 Vanderbilt Ave', 'address2': '', 'address3': None, 'city': 'Brooklyn', 'zip_code': '11238', 'country': 'US', 'state': 'NY', 'display_address': ['567 Vanderbilt Ave', 'Brooklyn, NY 11238']}, 'phone': '+17183999000', 'display_phone': '(718) 399-9000', 'distance': 3945.532545091288}, {'id': 'ysqgdbSrezXgVwER2kQWKA', 'alias': 'julianas-pizza-brooklyn-5', 'name': "Juliana's Pizza", ...
# {'businesses': [{'id': 'sUvoBG8t3eKC7WhJbnro2w', 'alias': 'the-pizza-place-hewlett', 'name': 'The Pizza Place', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/19ybffZ3cvRMqzZpSWaJrw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-pizza-place-hewlett?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg', 'review_count': 92, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}], 'rating': 3.5, 'coordinates': {'latitude': 40.640716, 'longitude': -73.699516}, 'transactions': [], 'price': '$$', 'location': {'address1': '1344 Broadway', 'address2': '', 'address3': '', 'city': 'Hewlett', 'zip_code': '11557', 'country': 'US', 'state': 'NY', 'display_address': ['1344 Broadway', 'Hewlett, NY 11557']}, 'phone': '+15163745900', 'display_phone': '(516) 374-5900', 'distance': 20271.82979363579}, {'id': 'EsHcyOLHaK76bQuU7bwiTw', 'alias': 'tonys-pizzeria-and-restaurant-brooklyn-3', 'name': "Tony's Pizzeria & Restaurant", 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wEPzpmEQ2Hd-WkeKUGe1Kg/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/tonys-pizzeria-and-restaurant-brooklyn-3?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg', 'review_count': 286, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}], 'rating': 4.5, 'coordinates': {'latitude': 40.699286, 'longitude': -73.918724}, 'transactions': ['pickup', 'delivery'], 'price': '$', 'location': {'address1': '443 Knickerbocker Ave', 'address2': '', 'address3': '', 'city': 'Brooklyn', 'zip_code': '11237', 'country': 'US', 'state': 'NY', 'display_address': ['443 Knickerbocker Ave', 'Brooklyn, NY 11237']}, 'phone': '+17184559664', 'display_phone': '(718) 455-9664', 'distance': 5503.669556667695}, {'id': 'AbDiDY7kYDSldaKbGpoSlg', 'alias': 'the-brooklyn-firefly-brooklyn', 'name': 'The Brooklyn Firefly', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4bTWP3GhL1kjuhlsduC71w/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/the-brooklyn-firefly-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg', 'review_count': 215, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'jazzandblues', 'title': 'Jazz & Blues'}, {'alias': 'bars', 'title': 'Bars'}], 'rating': 4.0, 'coordinates': {'latitude': 40.63468, 'longitude': -74.02631}, 'transactions': ['pickup', 'delivery'], 'price': '$$', 'location': {'address1': '7003 3rd Ave', 'address2': '', 'address3': None, 'city': 'Brooklyn', 'zip_code': '11209', 'country': 'US', 'state': 'NY', 'display_address': ['7003 3rd Ave', 'Brooklyn, NY 11209']}, 'phone': '+17188335000', 'display_phone': '(718) 833-5000', 'distance': 7588.967605653356}, {'id': '3VJwpmmeoPlCN3J5p5miEQ', 'alias': 'brooklyns-homeslice-pizzeria-brooklyn', 'name': "Brooklyn's Homeslice Pizzeria", 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0CxtRC4BfPobAfvBBLJH3g/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/brooklyns-homeslice-pizzeria-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg', 'review_count': 109, 'categories': [{'alias': 'pizza', 'title': 'Pizza'}], 'rating': 4.5, 'coordinates': {'latitude': 40.680702, 'longitude': -73.967455}, 'transactions': ['pickup', 'delivery'], 'price': '$', 'location': {'address1': '567 Vanderbilt Ave', 'address2': '', 'address3': None, 'city': 'Brooklyn', 'zip_code': '11238', 'country': 'US', 'state': 'NY', 'display_address': ['567 Vanderbilt Ave', 'Brooklyn, NY 11238']}, 'phone': '+17183999000', 'display_phone': '(718) 399-9000', 'distance': 3945.532545091288}, {'id': 'ysqgdbSrezXgVwER2kQWKA', 'alias': 'julianas-pizza-brooklyn-5', 'name': "Juliana's Pizza", ...
# ('sUvoBG8t3eKC7WhJbnro2w', 'The Pizza Place', 92, 3.5, 2, '1344 BroadwayHewlett, NY 11557')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 0
# ('EsHcyOLHaK76bQuU7bwiTw', "Tony's Pizzeria & Restaurant", 286, 4.5, 1, '443 Knickerbocker AveBrooklyn, NY 11237')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 1
# ('AbDiDY7kYDSldaKbGpoSlg', 'The Brooklyn Firefly', 215, 4.0, 2, '7003 3rd AveBrooklyn, NY 11209')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 2
# ('3VJwpmmeoPlCN3J5p5miEQ', "Brooklyn's Homeslice Pizzeria", 109, 4.5, 1, '567 Vanderbilt AveBrooklyn, NY 11238')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 3
# ('ysqgdbSrezXgVwER2kQWKA', "Juliana's Pizza", 2157, 4.5, 2, '19 Old Fulton StBrooklyn, NY 11201')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 4
# ('tZhguXirvAsEmJCbuym7BQ', "Jojo's Pizza", 11, 4.5, 'null', '9502 Church AveBrooklyn, NY 11212')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 5
# ('v1DHGRNCH9247WLYoaoA9A', "L'industrie Pizzeria", 506, 4.5, 1, '254 S 2nd StBrooklyn, NY 11211')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 6
# ('2ocEotgscaDAEr6Ok2_XAA', 'Pizzette', 14, 5.0, 2, '191 Graham AveBrooklyn, NY 11206')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 7
# ('E2RpnwMxgDHAWcsNMevhmg', 'Cuts & Slices', 103, 4.5, 1, '93 Howard AveBrooklyn, NY 11233')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 8
# ('c7f3V4h8kB4Pvgl3WzUKJg', 'Wood Fire Oven Pizza', 16, 4.0, 'null', '7901 17th AnenueBrooklyn, NY 11214')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 9
# ('Gr-5hjfSUO_ZAfOdwnqWpw', 'Family Pizza', 55, 4.0, 1, '720 Flatbush AveBrooklyn, NY 11225')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 10
# ('XB52IWIOK0AWx0NREpeNBw', "Sal & Paul's Pizzeria", 47, 4.5, 1, '1686 Pitkin AveBrooklyn, NY 11212')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 11
# ('OVyxBGSZ0x6rjyGkW6zCHA', 'Taverna Pizza', 2, 5.0, 'null', '663 Bay StStaten Island, NY 10304')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 12
# ('hSgD7ERSw0DE2RMzLGFiHg', 'Daddy Greens', 365, 4.0, 1, '1552 Fulton StBrooklyn, NY 11233')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 13
# ('C8j0q4Ma_S5hBGuAI-aaww', 'Di Fara Pizza', 3402, 4.0, 2, '1424 Ave JBrooklyn, NY 11230')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 14
# ('_sU0oNgNGyq1JFO8AGfB2A', 'Vesuvius Pizza', 25, 3.5, 1, '1800 Kings HwyBrooklyn, NY 11229')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 15
# ('b8xonwU5ZvxVauxNY07FsA', 'Brooklyn Pizza Crew', 133, 3.5, 2, '758 Nostrand AveBrooklyn, NY 11216')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 16
# ('MvkkAVNCFVmCWo8rXaTwBQ', 'Uncle Frankie’s', 23, 4.0, 'null', '3007 Fort Hamilton PkwyBrooklyn, NY 11218')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 17
# ('0o322YHC7J9ru5s_GHUM3Q', 'Mamma Roma', 2, 5.0, 'null', '524 4th AveBrooklyn, NY 11215')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 18
# ('BuoZEYr6Y8o_fX2xs060SA', 'Elegante Restaurant', 82, 4.0, 1, '9201 Rockaway Beach BlvdRockaway Beach, NY 11693')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 19
# ('xrgzB0pvsxeGEIboE6I2gg', "Patsy's Pizzeria", 512, 4.5, 2, '450 Dean StBrooklyn, NY 11217')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 20
# ('eTneVbjPKdo4gD9HfkDGdA', 'Santa Panza', 155, 4.5, 2, '1079 BroadwayBrooklyn, NY 11221')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 21
# ('RMKKsZYt4Xsyq3nRGFPqdA', 'Rocco Pizza', 170, 3.0, 1, '765 Dekalb AveBrooklyn, NY 11216')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 22
# ('m86CNmYThtzzWB3nPnrhbg', 'Emily - West Village', 609, 4.0, 2, '35 Downing StNew York, NY 10014')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 23
# ('VrLzehwrDEQ2XGWIaX-BYw', 'Jerusalem II Pizza', 20, 3.5, 1, '1312 Avenue JBrooklyn, NY 11230')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 24
# ('2ggi1luerd3Mf_C82JvCYg', "Grimaldi's Pizzeria", 4591, 3.5, 2, '1 Front StBrooklyn, NY 11201')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 25
# ('G84x335itBwT6gAMyfz8OQ', 'Marinara', 166, 4.0, 2, '1308 Peninsula BlvdHewlett, NY 11557')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 26
# ('kymVU-N3-bTK5KA84ZvIxg', "Yaya's Pizzeria", 14, 4.5, 1, '1675 Nostrand AveNew York, NY 11226')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 27
# ('pQo-KWQxuH26y0IzZbQj0A', "Joe & Sal's Pizza", 117, 4.5, 1, '842 Franklin AveBrooklyn, NY 11225')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 28
# ('xnw88LhmiI7_ktRTVYbESw', 'ZuriLee Restaurant', 260, 4.5, 2, '755 Flatbush AveBrooklyn, NY 11226')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 29
# ('uSOnbiYkOgrcIF6IyBxgHg', 'Slice Joint', 3, 5.0, 'null', '115 Delancey StNew York, NY 10002')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 30
# ('mZDNA6pjNR9nwJdbzjvk0A', 'Rocco Pizza', 62, 3.0, 1, '330 Halsey StBrooklyn, NY 11216')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 31
# ('oH58h122Jpv47pqXhL9p_Q', 'Original Pizza', 116, 4.0, 1, '9514 Ave LBrooklyn, NY 11236')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 32
# ('2xQmBB6w-W6lxiex80fA9A', "Luigi's Pizzeria", 239, 4.5, 1, '326 Dekalb AveBrooklyn, NY 11205')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 33
# ('2FgUndzCT_jJATbmrBDVBg', "Paulie Gee's Slice Shop", 165, 4.0, 1, '110 Franklin StBrooklyn, NY 11222')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 34
# ('g8Ai7LiusDgN_fpsdD8_fQ', "Joe & Sal's Pizza Of Fort Greene", 2, 5.0, 'null', '353 Myrtle AveBrooklyn, NY 11205')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 35
# ('IUYI_8EFBzouMfl81hofhg', 'Pizza Plus', 234, 4.0, 2, '359 7th AveBrooklyn, NY 11215')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 36
# ('t6TlsttYv1KhC5zCnOUM8A', 'La Bona Pizza & Pasta', 11, 4.0, 'null', '2426 Pitkin AveBrooklyn, NY 11208')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 37
# ('nLMJL4p7k4jNO4qLMc1wNg', 'Leo', 10, 4.0, 'null', '318 Grand StBrooklyn, NY 11211')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 38
# ('NDsa8EWd_tcfvUFbhPsTuQ', "Tony's Pizza", 139, 4.5, 1, '336 Knickerbocker AveBrooklyn, NY 11237')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 39
# ('jWunQ-f8CzRGwQVPhu0OdA', "Tony's Pizza", 9, 4.0, 'null', '312 Utica AveBrooklyn, NY 11213')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 40
# ('agG51WpNjAEAVTUCgX9INQ', 'On The Run Pizza', 22, 4.5, 1, '1627 Mermaid AveBrooklyn, NY 11224')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 41
# ('CmYpP-qt1YFDBrBjdPL97A', 'Amorina Cucina Rustica', 222, 4.0, 2, '624 Vanderbilt AveBrooklyn, NY 11238')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 42
# ('Td4FLmtMk1PYYisRuI2Qdg', 'Quentin Pizzeria & Restaurant', 24, 4.5, 1, '3211 Quentin RdBrooklyn, NY 11234')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 43
# ('3lqNnM93keyVXeWeURv7cg', "St John's Pizza", 4, 4.5, 'null', '1412 Saint Johns PlBrooklyn, NY 11213')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 44
# ('wTNUUoYUl3gox-gUAZ9bAA', "Peppino's Brick Oven Pizza & Restaurant", 405, 4.5, 2, '469 5th AveBrooklyn, NY 11215')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 45
# ('9DPI1WLAOfpiMXxHeQ0swg', 'Tailfeather', 15, 5.0, 'null', '581 Myrtle AveNew York, NY 11205')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 46
# ('02sAHm3_CsRKE2IeT5iaPA', 'Table 87 - Gowanus', 311, 4.0, 2, '473 3rd AveBrooklyn, NY 11215')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 47
# ('gtuRPv9oCJDcUxoODfl0KQ', 'Screamer’s Pizzeria', 96, 3.5, 'null', '685 Franklin AveBrooklyn, NY 11238')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 48
# ('UuY1QCxWybMF0IMxAYG06w', 'Emmy Squared - Brooklyn', 601, 4.0, 2, '364 Grand StBrooklyn, NY 11211')
# 2006 (HY000): MySQL server has gone away
# skipped entry number: 49

# %%
data
# Out:
# {'businesses': [{'id': 'sUvoBG8t3eKC7WhJbnro2w',
#    'alias': 'the-pizza-place-hewlett',
#    'name': 'The Pizza Place',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/19ybffZ3cvRMqzZpSWaJrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-pizza-place-hewlett?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 92,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.640716, 'longitude': -73.699516},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1344 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Hewlett',
#     'zip_code': '11557',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1344 Broadway', 'Hewlett, NY 11557']},
#    'phone': '+15163745900',
#    'display_phone': '(516) 374-5900',
#    'distance': 20271.82979363579},
#   {'id': 'EsHcyOLHaK76bQuU7bwiTw',
#    'alias': 'tonys-pizzeria-and-restaurant-brooklyn-3',
#    'name': "Tony's Pizzeria & Restaurant",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wEPzpmEQ2Hd-WkeKUGe1Kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tonys-pizzeria-and-restaurant-brooklyn-3?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 286,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.699286, 'longitude': -73.918724},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '443 Knickerbocker Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['443 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17184559664',
#    'display_phone': '(718) 455-9664',
#    'distance': 5503.669556667695},
#   {'id': '3VJwpmmeoPlCN3J5p5miEQ',
#    'alias': 'brooklyns-homeslice-pizzeria-brooklyn',
#    'name': "Brooklyn's Homeslice Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0CxtRC4BfPobAfvBBLJH3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyns-homeslice-pizzeria-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 109,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.680702, 'longitude': -73.967455},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '567 Vanderbilt Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['567 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17183999000',
#    'display_phone': '(718) 399-9000',
#    'distance': 3945.532545091288},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'alias': 'julianas-pizza-brooklyn-5',
#    'name': "Juliana's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/clscwgOF9_Ecq-Rwsq7jyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 2157,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7026153030093,
#     'longitude': -73.9934159993549},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '19 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966700',
#    'display_phone': '(718) 596-6700',
#    'distance': 7214.079408853298},
#   {'id': 'AbDiDY7kYDSldaKbGpoSlg',
#    'alias': 'the-brooklyn-firefly-brooklyn',
#    'name': 'The Brooklyn Firefly',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4bTWP3GhL1kjuhlsduC71w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brooklyn-firefly-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 215,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'jazzandblues', 'title': 'Jazz & Blues'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.63468, 'longitude': -74.02631},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '7003 3rd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11209',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7003 3rd Ave', 'Brooklyn, NY 11209']},
#    'phone': '+17188335000',
#    'display_phone': '(718) 833-5000',
#    'distance': 7588.967605653356},
#   {'id': 'tZhguXirvAsEmJCbuym7BQ',
#    'alias': 'jojos-pizza-brooklyn',
#    'name': "Jojo's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LOt0UBsTYWH-dVHhpph-5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jojos-pizza-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 11,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.65502, 'longitude': -73.91602},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '9502 Church Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11212',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9502 Church Ave', 'Brooklyn, NY 11212']},
#    'phone': '+17184853087',
#    'display_phone': '(718) 485-3087',
#    'distance': 1992.183471807299},
#   {'id': 'v1DHGRNCH9247WLYoaoA9A',
#    'alias': 'l-industrie-pizzeria-brooklyn',
#    'name': "L'industrie Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SRL_RztRRUijgQwt67daGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 506,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '254 S 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#    'phone': '+17185990002',
#    'display_phone': '(718) 599-0002',
#    'distance': 6771.011722454566},
#   {'id': 'E2RpnwMxgDHAWcsNMevhmg',
#    'alias': 'cuts-and-slices-brooklyn-3',
#    'name': 'Cuts & Slices',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iGo7yv-6OdBDsxL2FhPKww/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cuts-and-slices-brooklyn-3?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 103,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6854737, 'longitude': -73.9203186},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '93 Howard Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['93 Howard Ave', 'Brooklyn, NY 11233']},
#    'phone': '+17185522652',
#    'display_phone': '(718) 552-2652',
#    'distance': 4011.643918257051},
#   {'id': 'c7f3V4h8kB4Pvgl3WzUKJg',
#    'alias': 'wood-fire-oven-pizza-brooklyn-2',
#    'name': 'Wood Fire Oven Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bWuHQ9oBuInc0Q2mIviAQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wood-fire-oven-pizza-brooklyn-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 16,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.61239, 'longitude': -74.00072},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '7901 17th Anenue',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7901 17th Anenue', 'Brooklyn, NY 11214']},
#    'phone': '+17189757577',
#    'display_phone': '(718) 975-7577',
#    'distance': 6819.176769583841},
#   {'id': 'Gr-5hjfSUO_ZAfOdwnqWpw',
#    'alias': 'family-pizza-brooklyn',
#    'name': 'Family Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7iHFI9zOWztTW0PiNagE6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/family-pizza-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 55,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.65585, 'longitude': -73.96008},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '720 Flatbush Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['720 Flatbush Ave', 'Brooklyn, NY 11225']},
#    'phone': '+17184620639',
#    'display_phone': '(718) 462-0639',
#    'distance': 1798.4396068316894},
#   {'id': 'XB52IWIOK0AWx0NREpeNBw',
#    'alias': 'sal-and-pauls-pizzeria-brooklyn',
#    'name': "Sal & Paul's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2I9k6zpge1Gen5AkbWk8Ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sal-and-pauls-pizzeria-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 47,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.669419, 'longitude': -73.911059},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1686 Pitkin Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11212',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1686 Pitkin Ave', 'Brooklyn, NY 11212']},
#    'phone': '+17189220550',
#    'display_phone': '(718) 922-0550',
#    'distance': 3051.393402123398},
#   {'id': 'C8j0q4Ma_S5hBGuAI-aaww',
#    'alias': 'di-fara-pizza-brooklyn',
#    'name': 'Di Fara Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4dfe9qpe20P-vi3qFjWd4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/di-fara-pizza-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 3402,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.625093, 'longitude': -73.961531},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1424 Ave J',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11230',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1424 Ave J', 'Brooklyn, NY 11230']},
#    'phone': '+17182581367',
#    'display_phone': '(718) 258-1367',
#    'distance': 3559.746344303},
#   {'id': 'OVyxBGSZ0x6rjyGkW6zCHA',
#    'alias': 'taverna-pizza-staten-island',
#    'name': 'Taverna Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7Ypp5-dh5zs8hlz4vT0gnw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/taverna-pizza-staten-island?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 2,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.62588, 'longitude': -74.07504},
#    'transactions': [],
#    'location': {'address1': '663 Bay St',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10304',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['663 Bay St', 'Staten Island, NY 10304']},
#    'phone': '+17185247976',
#    'display_phone': '(718) 524-7976',
#    'distance': 11819.678653299356},
#   {'id': 'hSgD7ERSw0DE2RMzLGFiHg',
#    'alias': 'daddy-greens-brooklyn',
#    'name': 'Daddy Greens',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e9XRyluJfMa9eFlgoX0JDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/daddy-greens-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 365,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67969, 'longitude': -73.93883},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1552 Fulton St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1552 Fulton St', 'Brooklyn, NY 11233']},
#    'phone': '+17184842142',
#    'display_phone': '(718) 484-2142',
#    'distance': 3044.554067404408},
#   {'id': '_sU0oNgNGyq1JFO8AGfB2A',
#    'alias': 'vesuvius-pizza-brooklyn',
#    'name': 'Vesuvius Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-w2oDxpyfUhg7uZys-dIVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vesuvius-pizza-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 25,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6099, 'longitude': -73.95541},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1800 Kings Hwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11229',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1800 Kings Hwy', 'Brooklyn, NY 11229']},
#    'phone': '+17183399300',
#    'display_phone': '(718) 339-9300',
#    'distance': 4915.356312773627},
#   {'id': 'b8xonwU5ZvxVauxNY07FsA',
#    'alias': 'brooklyn-pizza-crew-brooklyn-2',
#    'name': 'Brooklyn Pizza Crew',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7ZadLDDel-WGWKmj6FfiuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brooklyn-pizza-crew-brooklyn-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 133,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.67279, 'longitude': -73.95053},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '758 Nostrand Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['758 Nostrand Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17183631122',
#    'display_phone': '(718) 363-1122',
#    'distance': 2462.9696684793803},
#   {'id': 'MvkkAVNCFVmCWo8rXaTwBQ',
#    'alias': 'uncle-frankie-s-brooklyn',
#    'name': 'Uncle Frankie’s',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lzJ7GjouJbncfENvQVeI6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uncle-frankie-s-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 23,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.64852, 'longitude': -73.9787},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '3007 Fort Hamilton Pkwy',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11218',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3007 Fort Hamilton Pkwy', 'Brooklyn, NY 11218']},
#    'phone': '+17188543462',
#    'display_phone': '(718) 854-3462',
#    'distance': 3348.843766322141},
#   {'id': 'xrgzB0pvsxeGEIboE6I2gg',
#    'alias': 'patsys-pizzeria-brooklyn-2',
#    'name': "Patsy's Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1n5xL5ojLR-_zseirQKaMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patsys-pizzeria-brooklyn-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 512,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6818695, 'longitude': -73.976181},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '450 Dean St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['450 Dean St', 'Brooklyn, NY 11217']},
#    'phone': '+17186222268',
#    'display_phone': '(718) 622-2268',
#    'distance': 4520.468918310525},
#   {'id': 'BuoZEYr6Y8o_fX2xs060SA',
#    'alias': 'elegante-restaurant-rockaway-beach-2',
#    'name': 'Elegante Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XnExnDXx2_ZveosMThiebw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elegante-restaurant-rockaway-beach-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 82,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.5864513001092,
#     'longitude': -73.8155078887939},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '9201 Rockaway Beach Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rockaway Beach',
#     'zip_code': '11693',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9201 Rockaway Beach Blvd',
#      'Rockaway Beach, NY 11693']},
#    'phone': '+17186343914',
#    'display_phone': '(718) 634-3914',
#    'distance': 12764.72560252341},
#   {'id': 'eTneVbjPKdo4gD9HfkDGdA',
#    'alias': 'santa-panza-brooklyn',
#    'name': 'Santa Panza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i2mhjGgXUCS1YDWt2urv6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/santa-panza-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 155,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6947, 'longitude': -73.93068},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1079 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1079 Broadway', 'Brooklyn, NY 11221']},
#    'phone': '+13474139695',
#    'display_phone': '(347) 413-9695',
#    'distance': 4763.659986591128},
#   {'id': 'RMKKsZYt4Xsyq3nRGFPqdA',
#    'alias': 'rocco-pizza-brooklyn',
#    'name': 'Rocco Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sQXR6VMCJ89kU8F4LAnkrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rocco-pizza-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 170,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.69224, 'longitude': -73.945849},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '765 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['765 Dekalb Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17182189200',
#    'display_phone': '(718) 218-9200',
#    'distance': 4466.5847003276385},
#   {'id': 'm86CNmYThtzzWB3nPnrhbg',
#    'alias': 'emily-west-village-new-york',
#    'name': 'Emily - West Village',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vtUUNneN3G81ME0SXp8BTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emily-west-village-new-york?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 609,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729330068469,
#     'longitude': -74.0038400073579},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '35 Downing St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35 Downing St', 'New York, NY 10014']},
#    'phone': '+19179356434',
#    'display_phone': '(917) 935-6434',
#    'distance': 10144.462798233651},
#   {'id': 'VrLzehwrDEQ2XGWIaX-BYw',
#    'alias': 'jerusalem-ii-pizza-brooklyn',
#    'name': 'Jerusalem II Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MX5OKOnzwo1HSBNnbGJ6Dw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jerusalem-ii-pizza-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 20,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.624848, 'longitude': -73.962807},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1312 Avenue J',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11230',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1312 Avenue J', 'Brooklyn, NY 11230']},
#    'phone': '+17183388156',
#    'display_phone': '(718) 338-8156',
#    'distance': 3640.3246788280035},
#   {'id': '2ocEotgscaDAEr6Ok2_XAA',
#    'alias': 'pizzette-brooklyn-2',
#    'name': 'Pizzette',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0tGfLRedLYS1u64w-AFyQQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzette-brooklyn-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 14,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.70858, 'longitude': -73.94357},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '191 Graham Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['191 Graham Ave', 'Brooklyn, NY 11206']},
#    'phone': '+19179091555',
#    'display_phone': '(917) 909-1555',
#    'distance': 6265.441413455934},
#   {'id': '2ggi1luerd3Mf_C82JvCYg',
#    'alias': 'grimaldis-pizzeria-brooklyn-4',
#    'name': "Grimaldi's Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TNKqW31PTvtSw6-Lbc1mtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 4591,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.702583, 'longitude': -73.9932413},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#    'phone': '+17188584300',
#    'display_phone': '(718) 858-4300',
#    'distance': 7201.993045049414},
#   {'id': 'G84x335itBwT6gAMyfz8OQ',
#    'alias': 'marinara-hewlett',
#    'name': 'Marinara',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Wu68y4jE3VmU5C0pZyI9HA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marinara-hewlett?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 166,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.644886, 'longitude': -73.704172},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1308 Peninsula Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Hewlett',
#     'zip_code': '11557',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1308 Peninsula Blvd', 'Hewlett, NY 11557']},
#    'phone': '+15167915205',
#    'display_phone': '(516) 791-5205',
#    'distance': 19859.16235458599},
#   {'id': 'kymVU-N3-bTK5KA84ZvIxg',
#    'alias': 'yayas-pizzeria-new-york',
#    'name': "Yaya's Pizzeria",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G2JvCnXQYJsaC5YiiAkONQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yayas-pizzeria-new-york?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 14,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.64529, 'longitude': -73.94881},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1675 Nostrand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11226',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1675 Nostrand Ave', 'New York, NY 11226']},
#    'phone': '+13476278399',
#    'display_phone': '(347) 627-8399',
#    'distance': 1111.963134072163},
#   {'id': 'pQo-KWQxuH26y0IzZbQj0A',
#    'alias': 'joe-and-sals-pizza-brooklyn',
#    'name': "Joe & Sal's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V4YjC0FeTG15Pkb12ypLgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-and-sals-pizza-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 117,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6694466400113,
#     'longitude': -73.9595866666786},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '842 Franklin Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['842 Franklin Ave', 'Brooklyn, NY 11225']},
#    'phone': '+17184848732',
#    'display_phone': '(718) 484-8732',
#    'distance': 2555.9368555160686},
#   {'id': 'uSOnbiYkOgrcIF6IyBxgHg',
#    'alias': 'slice-joint-new-york',
#    'name': 'Slice Joint',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J7g0XXShiiTaK6ro1r5ItQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/slice-joint-new-york?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71827, 'longitude': -73.98806},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '115 Delancey St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['115 Delancey St', 'New York, NY 10002']},
#    'phone': '+13324560129',
#    'display_phone': '(332) 456-0129',
#    'distance': 8405.92486070083},
#   {'id': 'mZDNA6pjNR9nwJdbzjvk0A',
#    'alias': 'rocco-pizza-brooklyn-2',
#    'name': 'Rocco Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CZycT69TC6uMAAUei6JFOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rocco-pizza-brooklyn-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 62,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.6826989780567,
#     'longitude': -73.9406578466271},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '330 Halsey St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['330 Halsey St', 'Brooklyn, NY 11216']},
#    'phone': '+17185739200',
#    'display_phone': '(718) 573-9200',
#    'distance': 3378.6254339015827},
#   {'id': '2FgUndzCT_jJATbmrBDVBg',
#    'alias': 'paulie-gees-slice-shop-brooklyn',
#    'name': "Paulie Gee's Slice Shop",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/So5FTaF3_Sf0fWYLhQ-Ofw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paulie-gees-slice-shop-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 165,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72836, 'longitude': -73.9572},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '110 Franklin St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['110 Franklin St', 'Brooklyn, NY 11222']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 8586.956344761837},
#   {'id': 'oH58h122Jpv47pqXhL9p_Q',
#    'alias': 'original-pizza-brooklyn-4',
#    'name': 'Original Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HVT0Vr_Vh52R_niODyPzCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/original-pizza-brooklyn-4?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 116,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.63781, 'longitude': -73.8963799},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '9514 Ave L',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11236',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9514 Ave L', 'Brooklyn, NY 11236']},
#    'phone': '+17185313559',
#    'display_phone': '(718) 531-3559',
#    'distance': 3979.0974694160172},
#   {'id': '2xQmBB6w-W6lxiex80fA9A',
#    'alias': 'luigis-pizzeria-brooklyn-4',
#    'name': "Luigi's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B3eNfBS1DTkTZ6fasVL01A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luigis-pizzeria-brooklyn-4?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 239,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6897, 'longitude': -73.965369},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '326 Dekalb Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['326 Dekalb Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187832430',
#    'display_phone': '(718) 783-2430',
#    'distance': 4698.6995897379675},
#   {'id': 'g8Ai7LiusDgN_fpsdD8_fQ',
#    'alias': 'joe-and-sals-pizza-of-fort-greene-brooklyn',
#    'name': "Joe & Sal's Pizza Of Fort Greene",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joe-and-sals-pizza-of-fort-greene-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 2,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.69335, 'longitude': -73.97214},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '353 Myrtle Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['353 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+19179094120',
#    'display_phone': '(917) 909-4120',
#    'distance': 5333.1617702573},
#   {'id': 'IUYI_8EFBzouMfl81hofhg',
#    'alias': 'pizza-plus-brooklyn-2',
#    'name': 'Pizza Plus',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/YDxMK-CQa1Xcr6HBkA3tMQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-plus-brooklyn-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 234,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.66585, 'longitude': -73.98211},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '359 7th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['359 7th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187685327',
#    'display_phone': '(718) 768-5327',
#    'distance': 3911.0852861698427},
#   {'id': 't6TlsttYv1KhC5zCnOUM8A',
#    'alias': 'la-bona-pizza-and-pasta-brooklyn',
#    'name': 'La Bona Pizza & Pasta',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b6NxN8Z-TyQFJn3V5YFsmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-bona-pizza-and-pasta-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 11,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67361, 'longitude': -73.88281},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '2426 Pitkin Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11208',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2426 Pitkin Ave', 'Brooklyn, NY 11208']},
#    'phone': '+17188726687',
#    'display_phone': '(718) 872-6687',
#    'distance': 5327.509994797856},
#   {'id': 'nLMJL4p7k4jNO4qLMc1wNg',
#    'alias': 'leo-brooklyn',
#    'name': 'Leo',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NlPSY-9-HhuFXSYc18RpFg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/leo-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71258, 'longitude': -73.95661},
#    'transactions': [],
#    'location': {'address1': '318 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['318 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17183846531',
#    'display_phone': '(718) 384-6531',
#    'distance': 6854.93022865415},
#   {'id': 'NDsa8EWd_tcfvUFbhPsTuQ',
#    'alias': 'tonys-pizza-brooklyn-5',
#    'name': "Tony's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eIxz0up4-4fBlUSaKGsKXw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tonys-pizza-brooklyn-5?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 139,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7010231018066,
#     'longitude': -73.9226455688477},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '336 Knickerbocker Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['336 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17184567020',
#    'display_phone': '(718) 456-7020',
#    'distance': 5593.972917791174},
#   {'id': 'jWunQ-f8CzRGwQVPhu0OdA',
#    'alias': 'tonys-pizza-brooklyn-13',
#    'name': "Tony's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RIFtILiY2wjvPyuTvfDh2A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tonys-pizza-brooklyn-13?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 9,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.667312, 'longitude': -73.93144},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '312 Utica Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11213',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['312 Utica Ave', 'Brooklyn, NY 11213']},
#    'phone': '+17187744440',
#    'display_phone': '(718) 774-4440',
#    'distance': 1794.9156184053343},
#   {'id': 'agG51WpNjAEAVTUCgX9INQ',
#    'alias': 'on-the-run-pizza-brooklyn',
#    'name': 'On The Run Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dKR3YcRUfpliR5xKt8KkCw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/on-the-run-pizza-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 22,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.57685, 'longitude': -73.98461},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '1627 Mermaid Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11224',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1627 Mermaid Ave', 'Brooklyn, NY 11224']},
#    'phone': '+17189466677',
#    'display_phone': '(718) 946-6677',
#    'distance': 9219.60481317279},
#   {'id': 'CmYpP-qt1YFDBrBjdPL97A',
#    'alias': 'amorina-cucina-rustica-brooklyn',
#    'name': 'Amorina Cucina Rustica',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DNl1dO2QeS5NCHXdUHshog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amorina-cucina-rustica-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 222,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.677558, 'longitude': -73.969207},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '624 Vanderbilt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['624 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17182303030',
#    'display_phone': '(718) 230-3030',
#    'distance': 3766.6659418240106},
#   {'id': 'gtuRPv9oCJDcUxoODfl0KQ',
#    'alias': 'screamer-s-pizzeria-brooklyn',
#    'name': 'Screamer’s Pizzeria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AFTlLKE77ovYyn8GdVrZRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/screamer-s-pizzeria-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 96,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.67512, 'longitude': -73.95623},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '685 Franklin Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['685 Franklin Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17186236000',
#    'display_phone': '(718) 623-6000',
#    'distance': 2909.555886174098},
#   {'id': 'UuY1QCxWybMF0IMxAYG06w',
#    'alias': 'emmy-squared-brooklyn-brooklyn-2',
#    'name': 'Emmy Squared - Brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vY5Issr9vLAYkboGXxQsDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/emmy-squared-brooklyn-brooklyn-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 601,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.712168, 'longitude': -73.955707},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '364 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['364 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17183604535',
#    'display_phone': '(718) 360-4535',
#    'distance': 6795.043303908554},
#   {'id': 'Td4FLmtMk1PYYisRuI2Qdg',
#    'alias': 'quentin-pizzeria-and-restaurant-brooklyn',
#    'name': 'Quentin Pizzeria & Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-UTQpsQOj5qM_p5HXAk_Ag/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/quentin-pizzeria-and-restaurant-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 24,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.61318, 'longitude': -73.939567},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '3211 Quentin Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11234',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3211 Quentin Rd', 'Brooklyn, NY 11234']},
#    'phone': '+17183765384',
#    'display_phone': '(718) 376-5384',
#    'distance': 4358.153109540088},
#   {'id': '3lqNnM93keyVXeWeURv7cg',
#    'alias': 'st-johns-pizza-brooklyn',
#    'name': "St John's Pizza",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-johns-pizza-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 4,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.6704753, 'longitude': -73.9316446},
#    'transactions': [],
#    'location': {'address1': '1412 Saint Johns Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11213',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1412 Saint Johns Pl', 'Brooklyn, NY 11213']},
#    'phone': '+17188040966',
#    'display_phone': '(718) 804-0966',
#    'distance': 2119.859195783193},
#   {'id': 'wTNUUoYUl3gox-gUAZ9bAA',
#    'alias': 'peppinos-brick-oven-pizza-and-restaurant-brooklyn-2',
#    'name': "Peppino's Brick Oven Pizza & Restaurant",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Mz8N4ggsttTNdvXBxJgr5A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peppinos-brick-oven-pizza-and-restaurant-brooklyn-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 405,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.668221, 'longitude': -73.986936},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '469 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['469 5th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17187687244',
#    'display_phone': '(718) 768-7244',
#    'distance': 4384.738675921156},
#   {'id': '02sAHm3_CsRKE2IeT5iaPA',
#    'alias': 'table-87-gowanus-brooklyn-2',
#    'name': 'Table 87 - Gowanus',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mpNlRWbkei5obwsVdE3HuA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/table-87-gowanus-brooklyn-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 311,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.670664, 'longitude': -73.991371},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '473 3rd Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['473 3rd Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17189658400',
#    'display_phone': '(718) 965-8400',
#    'distance': 4835.766839837786},
#   {'id': '0o322YHC7J9ru5s_GHUM3Q',
#    'alias': 'mamma-roma-brooklyn',
#    'name': 'Mamma Roma',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yVcioRpRq0g3su_F1smDIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mamma-roma-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 2,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.667659, 'longitude': -73.991393},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '524 4th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['524 4th Ave', 'Brooklyn, NY 11215']},
#    'phone': '+17183691300',
#    'display_phone': '(718) 369-1300',
#    'distance': 4706.508811291653},
#   {'id': 'fU22eRTnKLT2C-OFJ6eUGQ',
#    'alias': 'saraghina-brooklyn',
#    'name': 'Saraghina',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/91gieiePPSh6OuQJvrVirg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saraghina-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 852,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6835063, 'longitude': -73.9352006},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '435 Halsey St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['435 Halsey St', 'Brooklyn, NY 11233']},
#    'phone': '+17185740010',
#    'display_phone': '(718) 574-0010',
#    'distance': 3484.344416228906},
#   {'id': 'evhkqaDVxi3LGb39Rw-_Aw',
#    'alias': 'fazios-brooklyn',
#    'name': "Fazio's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6_Ky3Pki7y4Z1OyjkvB4WQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fazios-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 113,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69442, 'longitude': -73.91039},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '709 Knickerbocker Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['709 Knickerbocker Ave', 'Brooklyn, NY 11221']},
#    'phone': '+13475293222',
#    'display_phone': '(347) 529-3222',
#    'distance': 5289.648625050268}],
#  'total': 9900,
#  'region': {'center': {'longitude': -73.93936157226562,
#    'latitude': 40.652330148320374}}}

# %%
#getting review data
# Create a table for the reviews
def reviewCallGET(id_num):
    reviewEndpoint_base = 'https://api.yelp.com/v3/businesses/'
    reviewEndpoint_end = '/reviews'
    return requests.get(reviewEndpoint_base + id_num + reviewEndpoint_end,headers=headers)

test = 'ysqgdbSrezXgVwER2kQWKA'
# review_params={'id':'ysqgdbSrezXgVwER2kQWKA'}
review_data=reviewCallGET(test).json()
print(review_data)

# %%
#cleaning the businesses data

def cleanBusinessAndInsert(dat, keys, add_business):
    #loops each business
    print(dat)
    for i in range(len(dat['businesses'])):
        something = []

        #cleaning loop
        for x in keys:
            try :
                if (x == 'price'):
                    something.append(len(dat['businesses'][i][x]))
                elif (x == 'location'):
                    str_piece = ''
                    if (len(dat['businesses'][i][x]['display_address']) > 0):
                        str_piece = dat['businesses'][i][x]['display_address'][0]
                        if (len(dat['businesses'][i][x]['display_address']) > 1):
                            str_piece += dat['businesses'][i][x]['display_address'][1]
                    else:
                        str_piece = 'null'
                    something.append(str_piece)
                else:
                    something.append(dat['businesses'][i][x])
            except  KeyError:
                if x == 'id':
                    print('id if statement broken')
                something.append('null')
        #insert new data row
        data_business = (something[0], something[1], something[2],
                     something[3], something[4], something[5])
        print(data_business)
        try:
            cur.execute(add_business, data_business)
            print('success: {}'.format(i + currentOffset))
        except mysql.connector.Error as err:
            print(err)
            print('skipped entry number: {}'.format(i + currentOffset))

# %%
# Out:
# module

# %%
add_business = ("INSERT INTO businesses"
                "(businesses_id, businesses_name, businesses_review_count,"
                "businesses_rating, businesses_price, businesses_address) "
                "VALUES (%s, %s, %s, %s ,%s, %s)")
businessKeys = ['id', 'name', 'review_count', 'rating', 'price', 'location']

cur.execute(add_business, data_business)

# %%
data
# Out:
# {'businesses': [{'id': 'zFOtrdtiJ-1woygG7PoaNA',
#    'alias': 'bjs-pizzeria-east-orange',
#    'name': "Bj's Pizzeria",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SdSWluiAhZm5JZ4xJ48CHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bjs-pizzeria-east-orange?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 7,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.75183, 'longitude': -74.22777},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '230 Tremont Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'East Orange',
#     'zip_code': '07018',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['230 Tremont Ave', 'East Orange, NJ 07018']},
#    'phone': '+19736724340',
#    'display_phone': '(973) 672-4340',
#    'distance': 26714.701068113154},
#   {'id': 'lXzK0i9VnocLzPFwmEQ8Aw',
#    'alias': 'garlic-new-york-pizza-bar-new-york',
#    'name': 'Garlic New York Pizza Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jNenu8Pq4Qu4LT_CIArj8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garlic-new-york-pizza-bar-new-york?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 419,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.74514, 'longitude': -73.97584},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '629 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['629 2nd Ave', 'New York, NY 10016']},
#    'phone': '+16465599500',
#    'display_phone': '(646) 559-9500',
#    'distance': 10769.914018413687},
#   {'id': '73UL1--MFjXYCi1bwLMsuA',
#    'alias': 'torino-pizzeria-little-ferry',
#    'name': 'Torino Pizzeria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uIkGfgGUt4I3awZXv0PwkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/torino-pizzeria-little-ferry?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.84627, 'longitude': -74.039},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '153 Washington Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Little Ferry',
#     'zip_code': '07643',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['153 Washington Ave', 'Little Ferry, NJ 07643']},
#    'phone': '+12015183377',
#    'display_phone': '(201) 518-3377',
#    'distance': 23147.22622416743},
#   {'id': 'J28W8cm40Ghe-D4RX1iTtw',
#    'alias': 'boulevard-pizza-jamaica',
#    'name': 'Boulevard Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bEASrPXpCuB0pH6V-DBj1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boulevard-pizza-jamaica?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.694984, 'longitude': -73.789749},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '10901 Guy R Brewer Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Jamaica',
#     'zip_code': '11433',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10901 Guy R Brewer Blvd', 'Jamaica, NY 11433']},
#    'phone': '+17185262779',
#    'display_phone': '(718) 526-2779',
#    'distance': 13475.61559950125},
#   {'id': 'LhWKVtQNF2ugvZQ23vHvZg',
#    'alias': 'jiannettos-pizza-truck-new-york-2',
#    'name': "Jiannetto's Pizza Truck",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NpIR5rVnFo9SjfxBWeT4mQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jiannettos-pizza-truck-new-york-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 22,
#    'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7552637282396,
#     'longitude': -73.9752442659602},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '47th St & Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10017',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47th St & Park Ave', 'New York, NY 10017']},
#    'phone': '+19172877241',
#    'display_phone': '(917) 287-7241',
#    'distance': 11852.42172864384},
#   {'id': 'KscSF2Bnwa_wlg1MbdFjvQ',
#    'alias': 'tre-sorelle-new-york',
#    'name': 'Tre Sorelle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/cpiiqq2XuBlUE6-9xCDpMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tre-sorelle-new-york?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 146,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7149022072554,
#     'longitude': -74.0064939111471},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '61 Reade St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10007',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['61 Reade St', 'New York, NY 10007']},
#    'phone': '+12126191080',
#    'display_phone': '(212) 619-1080',
#    'distance': 8965.596380252317},
#   {'id': 'XYWKP5QHn7a-tmpDa1dn6w',
#    'alias': 'attilios-pizza-roslyn-heights-3',
#    'name': "Attilio's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wYJEnzZvJk_FaMn7LYZwWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/attilios-pizza-roslyn-heights-3?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 37,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78886, 'longitude': -73.65117},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '96 Mineola Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Roslyn Heights',
#     'zip_code': '11577',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['96 Mineola Ave', 'Roslyn Heights, NY 11577']},
#    'phone': '+15166211400',
#    'display_phone': '(516) 621-1400',
#    'distance': 28637.273699681424},
#   {'id': 'MHbxF-ZS918-ZoXKQPBEyg',
#    'alias': 'sotto-le-stelle-sunnyside',
#    'name': 'Sotto Le Stelle',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XXa_1w-s3LEml0UyNRu8nw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sotto-le-stelle-sunnyside?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 188,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.743656, 'longitude': -73.9201782},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4407 Queens Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Sunnyside',
#     'zip_code': '11104',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4407 Queens Blvd', 'Sunnyside, NY 11104']},
#    'phone': '+17186852086',
#    'display_phone': '(718) 685-2086',
#    'distance': 10282.92802532813},
#   {'id': '70c-BeXWi6mO9IN3_vnpdg',
#    'alias': 'new-park-pizza-howard-beach',
#    'name': 'New Park Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CKXME6c75Heq5VG9tMavhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/new-park-pizza-howard-beach?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 737,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6627403949909,
#     'longitude': -73.8403776268684},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '15671 Crossbay Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Howard Beach',
#     'zip_code': '11414',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15671 Crossbay Blvd', 'Howard Beach, NY 11414']},
#    'phone': '+17186413082',
#    'display_phone': '(718) 641-3082',
#    'distance': 8429.58028362777},
#   {'id': 'Wx8lTwG7b_sY4UsNrGyreg',
#    'alias': 'nathans-famous-brick-oven-pizza-brooklyn',
#    'name': "Nathan's Famous Brick Oven Pizza",
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nathans-famous-brick-oven-pizza-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 2,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.655609, 'longitude': -73.942736},
#    'transactions': [],
#    'location': {'address1': '500 Clarkson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11203',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['500 Clarkson Ave', 'Brooklyn, NY 11203']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 462.55775577926437},
#   {'id': 'sEBJD-yQHnbCz7vmNrfMvw',
#    'alias': 'crust-east-elmhurst-4',
#    'name': 'Crust',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/DlCaRzM62c1qoVU3HNg6qA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crust-east-elmhurst-4?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 57,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7706693479666, 'longitude': -73.86362180305},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': 'LaGuardia Aiport Queens',
#     'address2': 'Terminal C',
#     'address3': None,
#     'city': 'East Elmhurst',
#     'zip_code': '11371',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['LaGuardia Aiport Queens',
#      'Terminal C',
#      'East Elmhurst, NY 11371']},
#    'phone': '+18665083558',
#    'display_phone': '(866) 508-3558',
#    'distance': 14625.47143967903},
#   {'id': '2etp0QzYULJVQACbqAC4DA',
#    'alias': 'pizza-pros-maywood',
#    'name': 'Pizza Pros',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qg_t4GqvV8ygWBfDADPQ_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-pros-maywood?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 16,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.887772, 'longitude': -74.06528517},
#    'transactions': ['pickup'],
#    'location': {'address1': '105 Essex St',
#     'address2': '',
#     'address3': None,
#     'city': 'Maywood',
#     'zip_code': '07607',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['105 Essex St', 'Maywood, NJ 07607']},
#    'phone': '+12018456820',
#    'display_phone': '(201) 845-6820',
#    'distance': 28250.423801760397},
#   {'id': 'Wv5GwvugjZG6kXZ4yG9vGA',
#    'alias': 'ginos-pizza-elmont-2',
#    'name': 'Ginos pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-B7cMmrHNKMqkkBgWuqGKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginos-pizza-elmont-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 147,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.686663, 'longitude': -73.703062},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1615 Dutch Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmont',
#     'zip_code': '11003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1615 Dutch Broadway', 'Elmont, NY 11003']},
#    'phone': '+15165616664',
#    'display_phone': '(516) 561-6664',
#    'distance': 20291.664092534407},
#   {'id': 'CdqIBnH7CYmBJd13Op855A',
#    'alias': 'the-uptown-garrison-new-york-2',
#    'name': 'The Uptown Garrison',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MIBbLDpXkgy7Dt0hd8w1jA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-uptown-garrison-new-york-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 116,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8512380090093,
#     'longitude': -73.9392676530849},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '821 W 181st',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10033',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['821 W 181st', 'New York, NY 10033']},
#    'phone': '+19172614680',
#    'display_phone': '(917) 261-4680',
#    'distance': 22129.751022758934},
#   {'id': 'Aazjxg21VH2cncWYBAv68Q',
#    'alias': 'sottocasa-pizzeria-brooklyn-3',
#    'name': 'Sottocasa Pizzeria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MbBAMb3kb1VXtF9M5ptazA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sottocasa-pizzeria-brooklyn-3?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 615,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.688285, 'longitude': -73.989006},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '298 Atlantic Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['298 Atlantic Ave', 'Brooklyn, NY 11201']},
#    'phone': '+17188528758',
#    'display_phone': '(718) 852-8758',
#    'distance': 5788.560595464916},
#   {'id': 'YdFFUP3-PBzBsE3j75XwaQ',
#    'alias': 'panzerotti-bites-brooklyn',
#    'name': 'Panzerotti Bites',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HbRWIZCVfSCec8FSlvyLrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panzerotti-bites-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 117,
#    'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.683715, 'longitude': -73.99227},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '235 Smith St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Smith St', 'Brooklyn, NY 11231']},
#    'phone': '+17184889300',
#    'display_phone': '(718) 488-9300',
#    'distance': 5667.204556065232},
#   {'id': 'RDZsYPmmVkre6gptUp_iaQ',
#    'alias': 'zesty-pizzeria-and-salumeria-new-york-2',
#    'name': 'Zesty Pizzeria & Salumeria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/D9sbfhVFL7TrFn2oapAnIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zesty-pizzeria-and-salumeria-new-york-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 88,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7837296, 'longitude': -73.950798},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1670 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1670 3rd Ave', 'New York, NY 10128']},
#    'phone': '+12129872201',
#    'display_phone': '(212) 987-2201',
#    'distance': 14640.56367282957},
#   {'id': 'K_DG6WJLam56T0LD8tP9Mw',
#    'alias': 'napoli-pizza-newark',
#    'name': 'Napoli Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vQyLz-N28oPeWaO0Kd9CjQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/napoli-pizza-newark?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 33,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7226964, 'longitude': -74.1642197},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '275 Chestnut St',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07105',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['275 Chestnut St', 'Newark, NJ 07105']},
#    'phone': '+19735221950',
#    'display_phone': '(973) 522-1950',
#    'distance': 20514.682363544463},
#   {'id': 'zxNvP9A5gqJWg_2xQ8s43w',
#    'alias': 'pizza-classica-glendale',
#    'name': 'Pizza Classica',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Qv1q5JJvsSxOU3c_nP2Qlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-classica-glendale?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 396,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.706858, 'longitude': -73.855654},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '89-89 Union Tpke',
#     'address2': '',
#     'address3': None,
#     'city': 'Glendale',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['89-89 Union Tpke', 'Glendale, NY 11385']},
#    'phone': '+17188475001',
#    'display_phone': '(718) 847-5001',
#    'distance': 9305.301358266584},
#   {'id': 'EEJnLA1RPKFpoUCKejv5NQ',
#    'alias': 'grandpa-tonys-east-rockaway',
#    'name': "Grandpa Tony's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WqdbZToLD7GU5YTMEpr25Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grandpa-tonys-east-rockaway?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 61,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6386, 'longitude': -73.66027},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '101 Althouse Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'East Rockaway',
#     'zip_code': '11518',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['101 Althouse Ave', 'East Rockaway, NY 11518']},
#    'phone': '+15167998669',
#    'display_phone': '(516) 799-8669',
#    'distance': 23588.790306206847},
#   {'id': 'TWH4MjLtN1fKlF-7n6YXHg',
#    'alias': 'lil-frankies-new-york',
#    'name': "Lil' Frankie's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4_d7ZxSNaJVLaNEFhxbOAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lil-frankies-new-york?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 1085,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723625, 'longitude': -73.988555},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '19 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 1st Ave', 'New York, NY 10003']},
#    'phone': '+12124204900',
#    'display_phone': '(212) 420-4900',
#    'distance': 8939.742482238862},
#   {'id': '10JVmcrj0y9PGjkfomR4uw',
#    'alias': 'green-williamsburg-pizza-williamsburg',
#    'name': 'Green Williamsburg Pizza',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/green-williamsburg-pizza-williamsburg?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 1,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7066116333008,
#     'longitude': -73.958740234375},
#    'transactions': [],
#    'location': {'address1': '216 Ross St',
#     'address2': '',
#     'address3': '',
#     'city': 'Williamsburg',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['216 Ross St', 'Williamsburg, NY 11211']},
#    'phone': '+17183842540',
#    'display_phone': '(718) 384-2540',
#    'distance': 6252.259560635968},
#   {'id': '2b4seibfFBNTk7CKWuwjEA',
#    'alias': 'fiorella-pizzeria-italiana-mamaroneck',
#    'name': 'Fiorella Pizzeria Italiana',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/U4xlGHjHrQJ3y780YYecuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fiorella-pizzeria-italiana-mamaroneck?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 7,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.950521, 'longitude': -73.734536},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '260 Mamaroneck Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Mamaroneck',
#     'zip_code': '10543',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['260 Mamaroneck Ave', 'Mamaroneck, NY 10543']},
#    'phone': '+19146304000',
#    'display_phone': '(914) 630-4000',
#    'distance': 37374.093370369475},
#   {'id': 'VQfcz0tnoE2N42NtTKK2DA',
#    'alias': 'la-vera-pizzeria-new-york',
#    'name': 'La Vera Pizzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6qVWtabTBg0IcSwjJeRTIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-vera-pizzeria-new-york?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 35,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.74067, 'longitude': -73.98218},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '350 3rd Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['350 3rd Ave', 'New York, NY 10010']},
#    'phone': '+12122132222',
#    'display_phone': '(212) 213-2222',
#    'distance': 10462.087714153873},
#   {'id': 'CUPrO7jULZB5uvzp9l2Gzw',
#    'alias': 'salerno-pizza-astoria',
#    'name': 'Salerno Pizza',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/jc8olsvqffgSDTAY6reOmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/salerno-pizza-astoria?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 40,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.767289, 'longitude': -73.922863},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '29-24 30th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11102',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29-24 30th Ave', 'Astoria, NY 11102']},
#    'phone': '+17187771500',
#    'display_phone': '(718) 777-1500',
#    'distance': 12858.24740449043},
#   {'id': 'IKWRcmKE67dxSwh2kT4Gmw',
#    'alias': 'champions-pizza-city-of-orange',
#    'name': "Champion's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0MEnsvYdjXeM_kzmm-L3tA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/champions-pizza-city-of-orange?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77461, 'longitude': -74.23481},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '457 Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'City of Orange',
#     'zip_code': '07050',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['457 Main St', 'City of Orange, NJ 07050']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 28371.06684415462},
#   {'id': 'xzeBLxzdBgHR-wOHoWd0JA',
#    'alias': 'upper-west-side-pizza-new-york',
#    'name': 'Upper West Side Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VqhI_vND32_vtSCuhcHIyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upper-west-side-pizza-new-york?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 1,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7953199, 'longitude': -73.96613},
#    'transactions': [],
#    'location': {'address1': '808 Columbus Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['808 Columbus Ave', 'New York, NY 10025']},
#    'phone': '+12122226160',
#    'display_phone': '(212) 222-6160',
#    'distance': 15921.978472402772},
#   {'id': 'mdOqJ-bzi7i4AO2CBhcixg',
#    'alias': 'mike-and-maggies-pizzeria-whitestone-2',
#    'name': "Mike and Maggie's Pizzeria",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y9NZ0ns17k_HvKGSVJVZGA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mike-and-maggies-pizzeria-whitestone-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 76,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.786347, 'longitude': -73.8159809},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1527 149th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1527 149th St', 'Whitestone, NY 11357']},
#    'phone': '+17187670204',
#    'display_phone': '(718) 767-0204',
#    'distance': 18171.078162889233},
#   {'id': '1MURfN_0_tF1Bl0W-Ohb9g',
#    'alias': 'ninos-pizza-dumont',
#    'name': "Nino's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9pNV25af3t7Uwpl0MOmN0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ninos-pizza-dumont?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 17,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.9407311, 'longitude': -73.9911941},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '66 E Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Dumont',
#     'zip_code': '07628',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['66 E Madison Ave', 'Dumont, NJ 07628']},
#    'phone': '+12013851999',
#    'display_phone': '(201) 385-1999',
#    'distance': 32364.144616061556},
#   {'id': 'hFC2EpnPq33LfaewfOHWlA',
#    'alias': 'cafe-au-lee-brooklyn',
#    'name': "Cafe' Au Lee",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aPEl0f8YgcPe52Qj4Z9NWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-au-lee-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 5,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7023, 'longitude': -73.95577},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '193 Lee Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['193 Lee Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17183842379',
#    'display_phone': '(718) 384-2379',
#    'distance': 5723.608242479913},
#   {'id': '0ptEblu2pBxavB2zajhjmw',
#    'alias': 'golden-pizzeria-newark',
#    'name': 'Golden Pizzeria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b_zxN_GM-3SYJBxDz44jTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-pizzeria-newark?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 5,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7406921386719,
#     'longitude': -74.2012634277344},
#    'transactions': [],
#    'location': {'address1': '377 S Orange Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Newark',
#     'zip_code': '07103',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['377 S Orange Ave', 'Newark, NJ 07103']},
#    'phone': '+19736435003',
#    'display_phone': '(973) 643-5003',
#    'distance': 24163.517012277483},
#   {'id': 'sY5j4zQuWRGxHG6T7EunrQ',
#    'alias': 'artistic-pizza-new-york',
#    'name': 'Artistic Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/NzkMLJ0A7aP7pDGEvShByw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artistic-pizza-new-york?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 47,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73069, 'longitude': -74.00044},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '123 W 3rd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['123 W 3rd St', 'New York, NY 10012']},
#    'phone': '+19172615435',
#    'display_phone': '(917) 261-5435',
#    'distance': 10124.696028301583},
#   {'id': 'fKqk-30AJldp3CjIR8K98Q',
#    'alias': 'riverdale-pie-guys-bronx',
#    'name': 'Riverdale Pie Guys',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/buznxWYBuZhyP6MglcI3dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/riverdale-pie-guys-bronx?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 90,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.9053307, 'longitude': -73.8978577},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5784 Mosholu Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Bronx',
#     'zip_code': '10471',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5784 Mosholu Ave', 'Bronx, NY 10471']},
#    'phone': '+17187086128',
#    'display_phone': '(718) 708-6128',
#    'distance': 28344.72290802815},
#   {'id': 'T08IkirEPN5be9VNca0-vg',
#    'alias': 'pino-pizza-brooklyn',
#    'name': 'Pino Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vtDm-HpwqPqxqfsZpkOJKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pino-pizza-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 60,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6009756, 'longitude': -74.000594},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2025 Bath Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2025 Bath Ave', 'Brooklyn, NY 11214']},
#    'phone': '+17189969750',
#    'display_phone': '(718) 996-9750',
#    'distance': 7701.453357172361},
#   {'id': '1KeJfbG8H7xSZUJQuTsIIg',
#    'alias': 'mother-dough-brooklyn',
#    'name': 'Mother Dough',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cjpgRsS-6l_ry_UWwuk9Jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mother-dough-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 34,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.675389, 'longitude': -73.97513},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '72 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72 7th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+19292950012',
#    'display_phone': '(929) 295-0012',
#    'distance': 3959.3078977636233},
#   {'id': 'RtUbr2eVlN1XB3uavKTWSA',
#    'alias': 'pizza-supreme-bronx',
#    'name': 'Pizza Supreme',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ZSdAJEQvWIywqH5frtdAug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-supreme-bronx?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 20,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.8894686287964,
#     'longitude': -73.8988594797273},
#    'transactions': ['delivery'],
#    'location': {'address1': '5959 Broadway',
#     'address2': None,
#     'address3': None,
#     'city': 'Bronx',
#     'zip_code': '10463',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5959 Broadway', 'Bronx, NY 10463']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 26588.234716039657},
#   {'id': 'leXkmXdMyOM3ndOy098AUA',
#    'alias': '80-river-hoboken',
#    'name': '80 River',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Zgv5vfvCWU_eoAgUfWnKeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/80-river-hoboken?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 6,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.73618, 'longitude': -74.029424},
#    'transactions': [],
#    'location': {'address1': '80 River St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['80 River St', 'Hoboken, NJ 07030']},
#    'phone': '+12014207070',
#    'display_phone': '(201) 420-7070',
#    'distance': 12024.605815504223},
#   {'id': 'VhDkLQ9xBEoq-mYYqU8-Hg',
#    'alias': 'omg-pizzeria-brooklyn',
#    'name': 'OMG Pizzeria',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oud3D8acLcxTDlYRQIjUrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/omg-pizzeria-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 133,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.69817, 'longitude': -73.92558},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '1307 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1307 Myrtle Ave', 'Brooklyn, NY 11221']},
#    'phone': '+17184554550',
#    'display_phone': '(718) 455-4550',
#    'distance': 5226.671270220903},
#   {'id': 'VrP6mI9Ihf2qt8dH6XwnYg',
#    'alias': 'protos-pizza-new-york-9',
#    'name': "Proto's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AdbSxI5lZGb6EBFJfvQAOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/protos-pizza-new-york-9?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 100,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.725353, 'longitude': -73.989746},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '50 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['50 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12124324044',
#    'display_phone': '(212) 432-4044',
#    'distance': 9165.059692564573},
#   {'id': 'vTn3ww550Rnhz9naIxtjww',
#    'alias': 'brunetti-pizza-new-york',
#    'name': 'Brunetti Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GFEmMtaYhoxsMcZZf3CjkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/brunetti-pizza-new-york?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 280,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73829, 'longitude': -74.0054},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '626 Hudson St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['626 Hudson St', 'New York, NY 10014']},
#    'phone': '+12122555699',
#    'display_phone': '(212) 255-5699',
#    'distance': 11058.395227384604},
#   {'id': 'KE9btlMu1BUpGnskAgFMag',
#    'alias': 'urban-bricks-pizza-kearny',
#    'name': 'Urban Bricks Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MXOWhrCYwEXaRU5sWwvN5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/urban-bricks-pizza-kearny?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 55,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.759322, 'longitude': -74.1604882},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '190 Passaic Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Kearny',
#     'zip_code': '07032',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['190 Passaic Ave', 'Kearny, NJ 07032']},
#    'phone': '+15512748000',
#    'display_phone': '(551) 274-8000',
#    'distance': 22095.457340403165},
#   {'id': 'mpS38CQozjwcWPa231SouQ',
#    'alias': 'roman-pizza-1-long-island-city',
#    'name': 'Roman Pizza 1',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k9JDSKIxi0V5erK9G295Rw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/roman-pizza-1-long-island-city?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 1,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7560312, 'longitude': -73.9407009},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '39-42 21st St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-42 21st St', 'Long Island City, NY 11101']},
#    'phone': '+17183975007',
#    'display_phone': '(718) 397-5007',
#    'distance': 11539.867465103016},
#   {'id': 'UxD3HRvbpFPyPVq_6KW3RA',
#    'alias': 'patricias-of-holmdel-holmdel',
#    'name': "Patricia's of Holmdel",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wLAUcS3QyR3F2mLXMRbUcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/patricias-of-holmdel-holmdel?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 253,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.4128567, 'longitude': -74.1472072},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2132 Rt 35 S',
#     'address2': '',
#     'address3': '',
#     'city': 'Holmdel',
#     'zip_code': '07733',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['2132 Rt 35 S', 'Holmdel, NJ 07733']},
#    'phone': '+17322750234',
#    'display_phone': '(732) 275-0234',
#    'distance': 32040.25009575753},
#   {'id': '_3S_nIiJECWxJwOCD3l4zw',
#    'alias': 'la-vita-mia-pizzeria-and-the-cal-zone-staten-island',
#    'name': 'La Vita Mia Pizzeria & The Cal-ZONE',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eBmDRFaj6cTCXMv91v0alA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-vita-mia-pizzeria-and-the-cal-zone-staten-island?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'catering', 'title': 'Caterers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.566402, 'longitude': -74.183098},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1281 Arthur Kill Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Staten Island',
#     'zip_code': '10312',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1281 Arthur Kill Rd', 'Staten Island, NY 10312']},
#    'phone': '+13472152210',
#    'display_phone': '(347) 215-2210',
#    'distance': 22686.756040273427},
#   {'id': 'yP1oD5nCm6vMY5-IaDBoGQ',
#    'alias': 'rocky-sullivans-brooklyn',
#    'name': "Rocky Sullivan's",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/9vfmvmYq8XCd-ShSczM83g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rocky-sullivans-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 81,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'irish_pubs', 'title': 'Irish Pub'},
#     {'alias': 'musicvenues', 'title': 'Music Venues'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67315, 'longitude': -74.01224},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '46 Beard St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11231',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['46 Beard St', 'Brooklyn, NY 11231']},
#    'phone': '+17182468050',
#    'display_phone': '(718) 246-8050',
#    'distance': 6565.251457458319},
#   {'id': 'nykUuNS2VaoMqjkJXpcVZQ',
#    'alias': 'supreme-pizzeria-and-restaurant-queens',
#    'name': 'Supreme Pizzeria and Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/N8R-QYlRmu0yFcXcaJnydQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/supreme-pizzeria-and-restaurant-queens?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7275599, 'longitude': -73.73098},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '236-09 Braddock Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Queens',
#     'zip_code': '11426',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['236-09 Braddock Ave', 'Queens, NY 11426']},
#    'phone': '+17183437100',
#    'display_phone': '(718) 343-7100',
#    'distance': 19454.07856340426},
#   {'id': 'VjuZ07nv_psJkn4xDLCw5g',
#    'alias': 'eat-n-run-cafe-brooklyn',
#    'name': 'Eat N Run Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9xdRYAl9LAD5Uqrsmt91mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eat-n-run-cafe-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 16,
#    'categories': [{'alias': 'kosher', 'title': 'Kosher'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.59409, 'longitude': -73.96113},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2574 Coney Island Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11223',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2574 Coney Island Ave', 'Brooklyn, NY 11223']},
#    'phone': '+17186760522',
#    'display_phone': '(718) 676-0522',
#    'distance': 6731.55849602057},
#   {'id': 'PDhIpeEtk-sNuBCwUNiIKw',
#    'alias': 'hungry-like-the-wolf-hoboken-2',
#    'name': 'Hungry Like the Wolf',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jSSF5lT84KmHrc0ug5W48g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hungry-like-the-wolf-hoboken-2?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 10,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73964, 'longitude': -74.04271},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '700 1st St',
#     'address2': '',
#     'address3': None,
#     'city': 'Hoboken',
#     'zip_code': '07030',
#     'country': 'US',
#     'state': 'NJ',
#     'display_address': ['700 1st St', 'Hoboken, NJ 07030']},
#    'phone': '+12016563026',
#    'display_phone': '(201) 656-3026',
#    'distance': 13042.409525656258},
#   {'id': 'nI7McGALDI-tT82bNPpHhg',
#    'alias': 'frank-pizzeria-restaurant-brooklyn',
#    'name': 'Frank Pizzeria Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/HIJoDsAGQP-mNmvBQt-8Og/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/frank-pizzeria-restaurant-brooklyn?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 3,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.6841599169227,
#     'longitude': -73.8708301261067},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '3381 Fulton St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11208',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['3381 Fulton St', 'Brooklyn, NY 11208']},
#    'phone': '+13474350000',
#    'display_phone': '(347) 435-0000',
#    'distance': 6777.537749289894},
#   {'id': '32VbG_XgkZIuye0PV-BxaA',
#    'alias': 'zero-otto-nove-new-york-3',
#    'name': 'Zero Otto Nove',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B1rfkFnHFfmbci_miI1slw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zero-otto-nove-new-york-3?adjust_creative=F_8ybsDGOxK8FdQaLMXsGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=F_8ybsDGOxK8FdQaLMXsGg',
#    'review_count': 476,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7407551035259,
#     'longitude': -73.9914887388588},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 W 21st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 W 21st St', 'New York, NY 10010']},
#    'phone': '+12122420899',
#    'display_phone': '(212) 242-0899',
#    'distance': 10769.787211681649}],
#  'total': 9900,
#  'region': {'center': {'longitude': -73.93936157226562,
#    'latitude': 40.652330148320374}}}

# %%
cur.execute('''
DROP TABLE businesses
;
''')

# %%
# import pandas as pd

# cur.execute("""
# SELECT * 
# FROM YelpPizza.businesses
# ORDER BY businesses_rating
# ;
# """)
# df = pd.DataFrame(cur.fetchall())
# df.columns = [x[0] for x in cur.description]
df
# Out:
#               businesses_id          businesses_name  businesses_review_count  \
# 0    b6QXXgkcObAzb1EQyQx5Nw    Taco Bell / Pizza Hut                        0
# 1    5wfKQ8wQOKz56Gj7GcyrfQ           Domino's Pizza                        3
# 2    DMkBrk9SUXcwCkXSyT787A            Keep it Halal                        2
# 3    EVD6nDw-iXoPAFpf1jn_9w           Domino's Pizza                       78
# 4    KEBeh8JBy8z5tkupaV9IZQ      Gramma's pizza shop                        1
# ..                      ...                      ...                      ...
# 995  yyrXCNbXdXd6C6HQpYRWrQ    Heights Bar and Grill                        1
# 996  z5IlqGy5KMath_ieugBlMg                     Tale                       12
# 997  zcxZLypXNAi6E3G0T6ZVIQ   Joanne's Gourmet Pizza                        3
# 998  zFdIHdzQ1DuE_XSAKP4xdg     Tasty Munchies Pizza                        1
# 999  zv0c9dwh3_TwHaaZjEzsAQ  Tony Pepperoni Pizzeria                       10
#
#     businesses_rating  businesses_price  \
# 0                0.00                 0
# 1                1.00                 0
# 2                1.00                 0
# 3                1.00                 1
# 4                1.00                 0
# ..                ...               ...
# 995              5.00                 0
# 996              5.00                 0
# 997              5.00                 0
# 998              5.00                 0
# 999              5.00                 1
#
#                           businesses_address
# 0                                 3908th Ave
# 1           886 Dekalb AveBrooklyn, NY 11221
# 2    1162 Coney Island AveBrooklyn, NY 11230
# 3        241 Rockaway PkwyBrooklyn, NY 11212
# 4           99B Featherbed LnBronx, NY 10452
# ..                                       ...
# 995        766 Classon AveBrooklyn, NY 11238
# 996            683 5th AveBrooklyn, NY 11215
# 997      161 E Jericho TpkeMineola, NY 11501
# 998       206 Rivington StNew York, NY 10002
# 999          7502 18th AveBrooklyn, NY 11214
#
# [1000 rows x 6 columns]
